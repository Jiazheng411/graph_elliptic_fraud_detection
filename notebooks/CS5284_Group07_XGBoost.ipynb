# %% [markdown]
# # CS5284 Group07 - XGBoost

# %%
# To run certain networkX function in parallel
# !nvcc --version
# !pip install nx-cugraph-cu12 --extra-index-url=https://pypi.nvidia.com
# %env NX_CUGRAPH_AUTOCONFIG=True
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Requirement already satisfied: nx-cugraph-cu12 in /usr/local/lib/python3.12/dist-packages (25.6.0)
# Requirement already satisfied: cupy-cuda12x>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from nx-cugraph-cu12) (13.3.0)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from nx-cugraph-cu12) (3.5)
# Requirement already satisfied: numpy<3.0a0,>=1.23 in /usr/local/lib/python3.12/dist-packages (from nx-cugraph-cu12) (2.0.2)
# Requirement already satisfied: pylibcugraph-cu12==25.6.* in /usr/local/lib/python3.12/dist-packages (from nx-cugraph-cu12) (25.6.0)
# Requirement already satisfied: libcugraph-cu12==25.6.* in /usr/local/lib/python3.12/dist-packages (from pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (25.6.0)
# Requirement already satisfied: pylibraft-cu12==25.6.* in /usr/local/lib/python3.12/dist-packages (from pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (25.6.0)
# Requirement already satisfied: rmm-cu12==25.6.* in /usr/local/lib/python3.12/dist-packages (from pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (25.6.0)
# Requirement already satisfied: libraft-cu12==25.6.* in /usr/local/lib/python3.12/dist-packages (from libcugraph-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (25.6.0)
# Requirement already satisfied: cuda-python<13.0a0,>=12.6.2 in /usr/local/lib/python3.12/dist-packages (from pylibraft-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (12.6.2.post1)
# Requirement already satisfied: librmm-cu12==25.6.* in /usr/local/lib/python3.12/dist-packages (from rmm-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (25.6.0)
# Requirement already satisfied: nvidia-cublas-cu12 in /usr/local/lib/python3.12/dist-packages (from libraft-cu12==25.6.*->libcugraph-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (12.6.4.1)
# Requirement already satisfied: nvidia-curand-cu12 in /usr/local/lib/python3.12/dist-packages (from libraft-cu12==25.6.*->libcugraph-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12 in /usr/local/lib/python3.12/dist-packages (from libraft-cu12==25.6.*->libcugraph-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12 in /usr/local/lib/python3.12/dist-packages (from libraft-cu12==25.6.*->libcugraph-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (12.5.4.2)
# Requirement already satisfied: nvidia-nccl-cu12>=2.19 in /usr/local/lib/python3.12/dist-packages (from libraft-cu12==25.6.*->libcugraph-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (2.27.3)
# Requirement already satisfied: rapids-logger==0.1.* in /usr/local/lib/python3.12/dist-packages (from libraft-cu12==25.6.*->libcugraph-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (0.1.19)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x>=12.0.0->nx-cugraph-cu12) (0.8.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12->libraft-cu12==25.6.*->libcugraph-cu12==25.6.*->pylibcugraph-cu12==25.6.*->nx-cugraph-cu12) (12.6.85)
# env: NX_CUGRAPH_AUTOCONFIG=True

# %%
# Import
import pandas as pd
import networkx as nx
from xgboost import DMatrix, train
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

nx.config.warnings_to_ignore.add("cache") # Ignore networkx cugraph warnings

# %% [markdown]
# # Tabular Features Only

# %% [markdown]
# ## Data Preparation

# %%
# Load data from CSV file
# data = pd.read_csv('elliptic_bitcoin_dataset_50K_samples_final.csv', header=None)
data = pd.read_csv('elliptic_txs_features_labelled_only.csv', header=None, low_memory=False)

# Separate features and target
X = data.iloc[:, 1:-1]   # all columns except last and first column (txn id)
Y = data.iloc[:, -1]    # last column

# Remap Y labels to be either 0 or 1
Y = Y.map({2: 0, 1: 1})

# %%
# Split into train and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=1)

# %%
# Create DMatrix from X and Y
dtrain = DMatrix(X_train, Y_train)
dtest = DMatrix(X_test, Y_test)

# %% [markdown]
# ## Train Model

# %%
# Set XGBoost parameters
params = {
    'objective': 'binary:logistic',
    'learning_rate': 0.1,
    'random_state': 1
}

# %%
# Train the model
model = train(params, dtrain)

# %% [markdown]
# ## Test Model

# %%
# Predict
preds = model.predict(dtest) # output a probability
preds_binary = (preds > 0.5).astype(int) # convert back to binary for comparison

# Calculate error
acc = accuracy_score(Y_test, preds_binary)
prec = precision_score(Y_test, preds_binary)
rec = recall_score(Y_test, preds_binary)
f1  = f1_score(Y_test, preds_binary)
print("Accuracy: ", acc)
print("Precision: ", prec)
print("Recall: ", rec)
print("F1 Score: ", f1)
# Out:
# Accuracy:  0.9750880508547376
# Precision:  0.9976133651551312
# Recall:  0.7437722419928826
# F1 Score:  0.8521916411824668

# %% [markdown]
# # Tabular + Graph Features

# %%
# Load data from CSV file
data = pd.read_csv('elliptic_txs_features_labelled_only_with_graph_feature.csv', header=None, low_memory=False)
edgelist = pd.read_csv('elliptic_txs_edgelist_labelled_only.csv', header=None, low_memory=False)

# %% [markdown]
# ## Prepare Graph Features
# - PageRank
# - Betweeness Centrality
# - In-degree
#
# Note: We already included the in-degree feature in the features dataset

# %%
# Page Rank
graph = nx.from_pandas_edgelist(edgelist, source=0, target=1, create_using=nx.DiGraph())
pageRankScores = nx.pagerank(graph)

print(pageRankScores)

betweennessScores = nx.betweenness_centrality(graph, k=10000, seed=1) # Take approx ~1/3 of nodes as sample
print(betweennessScores)

# Add to existing DF
data.insert(len(data.columns) - 1, "pagerank", '')
data["pagerank"] = data[0].map(pageRankScores)

data.insert(len(data.columns) - 1, "betweenness", '')
data["betweenness"] = data[0].map(betweennessScores)
# print(data)
# Out:
0, 230331387: 0.0, 231993291: 2.7876895458689432e-08, 232440020: 7.108608457429e-08, 232440017: 6.551070441673801e-08, 230465231: 0.0, 5530776: 0.0, 3891191: 0.0, 3851887: 0.0, 226890719: 0.0, 230540196: 0.0, 232349072: 0.0, 20299716: 0.0, 214488573: 0.0, 230473461: 7.526762146881083e-08, 86353799: 0.0, 232472561: 0.0, 3114489: 0.0, 107227719: 0.0, 230451739: 0.0, 230451730: 1.4867677755603381e-08, 13285375: 0.0, 230457093: 0.0, 230457090: 1.672613691994229e-08, 233842379: 0.0, 232448785: 5.5753792693735704e-09, 232448783: 0.0, 232440028: 5.157225757557171e-08, 3877118: 5.5753792693735704e-09, 230872133: 0.0, 232039890: 0.0, 232039888: 1.3938447729344716e-08, 230453424: 3.7169194389008453e-09, 232047414: 0.0, 232047419: 0.0, 230339477: 0.0, 232039381: 0.0, 2718195: 0.0, 2865010: 0.0, 60492027: 8.363068459971146e-09, 230473314: 0.0, 230523246: 0.0, 230457870: 8.363068459971146e-09, 232679753: 0.0, 231573972: 0.0, 232959353: 0.0, 230579331: 0.0, 231995683: 0.0, 230473477: 2.2301517077494282e-08, 206225929: 2.7876896346867852e-09, 11340045: 0.0, 230438474: 8.641837467848745e-08, 230438471: 2.5786127366700384e-07, 230468042: 0.0, 230468036: 1.3938447729344716e-08, 231995763: 0.0, 230596505: 0.0, 31188978: 0.0, 59397801: 8.363068459971146e-09, 230555921: 0.0, 232072340: 0.0, 230405994: 0.0, 91411167: 5.5753792693735704e-09, 232457915: 0.0, 232457913: 2.7876896346867852e-09, 232901095: 0.0, 57801713: 0.0, 232039861: 0.0, 230468700: 0.0, 3408976: 0.0, 232047756: 0.0, 232034707: 1.3938447729344716e-08, 71724941: 5.5753792693735704e-09, 2717498: 0.0, 230969607: 0.0, 230968958: 0.0, 232941800: 0.0, 232906716: 1.6679675240993674e-07, 232448383: 1.3706140578051418e-07, 71369016: 0.0, 230649126: 0.0, 84863672: 0.0, 3402165: 0.0, 232456339: 0.0, 232034945: 1.0035682151965375e-07, 2304 ...

# %%
# Separate features and target
X = data.iloc[:, 1:-1]   # all columns except last and first column (txn id)
Y = data.iloc[:, -1]    # last column (target)

# Remap Y labels to be either 0 or 1
Y = Y.map({2: 0, 1: 1})

# %%
# Split into train and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=1)

# %% [markdown]
# ## Train Model

# %%
# Create DMatrix from X and Y
dtrain = DMatrix(X_train, Y_train)
dtest = DMatrix(X_test, Y_test)

# %%
# Set XGBoost parameters
params = {
    'objective': 'binary:logistic',
    'learning_rate': 0.1,
    'random_state': 1
}

# %%
# Train the model
model = train(params, dtrain)

# %% [markdown]
# ## Test Model

# %%
# Predict
preds = model.predict(dtest) # output a probability
preds_binary = (preds > 0.5).astype(int) # convert back to binary for comparison

# Calculate error
acc = accuracy_score(Y_test, preds_binary)
prec = precision_score(Y_test, preds_binary)
rec = recall_score(Y_test, preds_binary)
f1  = f1_score(Y_test, preds_binary)
print("Accuracy: ", acc)
print("Precision: ", prec)
print("Recall: ", rec)
print("F1 Score: ", f1)
# Out:
# Accuracy:  0.9779228588609226
# Precision:  0.9977037887485649
# Recall:  0.7731316725978647
# F1 Score:  0.8711779448621554
